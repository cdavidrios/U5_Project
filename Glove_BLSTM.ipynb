# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/rramosp/2020.deeplearning/master/init.py
from init import init; init(force_download=False)
# Out:
# replicating local resources

# %%
#!python -m spacy download en_core_web_lg

# %%
#%% Import Libraries
import string
import spacy
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import unicodedata
from nltk.stem.porter import PorterStemmer
from nltk import wordpunct_tokenize
import re
import gensim.downloader as api
#import en_core_web_lg
import pandas as pd

#%% noPunctuation
def noPunctuation(text):
         
    text= [char for char in text if char not in string.punctuation]
    nopunctuation=''.join(text)
           
    nopunctuation.split()

    return nopunctuation
#%%

def noPunctuationExtra(text):    
    texttoP=text
    forbidden1 = ('?', '¿', '¡', '!', ',', '.', ';', ':','xxxx')
    for i in range (len(forbidden1)):    
        idx=[n for n in range(len(texttoP)) if text.find(forbidden1[i], n) == n]
        if len(idx)!=0:
            for j in range(len(idx)):
                texttoP=texttoP.replace(texttoP[idx[j]],' ')
    return texttoP

#%%
def removeNumbers(text):
    text = ''.join([i for i in text if not i.isdigit()])
    
    return text

#%% StopWordsRemoval
def StopWordsRemoval(text):

    stopwords_aux = stopwords.words('english')
    #stopwords_aux.append('us')
    #Now eliminate stopwords
    clean_sentence= [word for word in text.split() if word.lower() not in stopwords_aux]
    clean_sentence=' '.join(clean_sentence)

    return clean_sentence

#%% Lemmatizer
#nlp = spacy.load('en_core_web_lg')
#nlp = en_core_web_lg.load()

def Lemmatizer(text,language='english'):

    doc = nlp(text)
    tokenLemma=[]
    for token in doc:
        #print(token, token.lemma, token.lemma_)
        if (token.lemma_ =="-PRON-"):
            tokenLemma.append(token.text)
        else:
            tokenLemma.append(token.lemma_)
    tokenLemma=' '.join(tokenLemma)
    return tokenLemma

              
#%% toLowerCase
def toLowerCase(text):
    text=text.lower()
    return text

#%% remove 'um' and 'uh'
def muletsRemoval(text):
    text=text.replace(' XXXX',"")
    text=text.replace(' um',"")
    text=text.replace(' Um',"")
    text=text.replace(' uh',"")
    text=text.replace(' Uh',"")

    return text

## Clean text of unique characters
def CleanText(text):
    text_split=  text.split()  
    aux=[]
    for i in range(0,len(text_split)):
        if (len(text_split[i])>=2):
            aux.append(text_split[i])
    cleantext=' '.join(aux)
    return(cleantext)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !wget nc https://github.com/cristianru31/dataset_U5/blob/master/data_U5.zip?raw=true -O data_U5.zip 
# !unzip data_U5.zip
# Out:
# --2020-06-08 20:52:10--  http://nc/
# Resolving nc (nc)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘nc’
# --2020-06-08 20:52:10--  https://github.com/cristianru31/dataset_U5/blob/master/data_U5.zip?raw=true
# Resolving github.com (github.com)... 140.82.118.4
# Connecting to github.com (github.com)|140.82.118.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cristianru31/dataset_U5/raw/master/data_U5.zip [following]
# --2020-06-08 20:52:10--  https://github.com/cristianru31/dataset_U5/raw/master/data_U5.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/cristianru31/dataset_U5/master/data_U5.zip [following]
# --2020-06-08 20:52:10--  https://raw.githubusercontent.com/cristianru31/dataset_U5/master/data_U5.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 623544 (609K) [application/zip]
# Saving to: ‘data_U5.zip’
#
# data_U5.zip         100%[===================>] 608.93K  --.-KB/s    in 0.04s
#
# 2020-06-08 20:52:12 (14.3 MB/s) - ‘data_U5.zip’ saved [623544/623544]
#
# FINISHED --2020-06-08 20:52:12--
# Total wall clock time: 1.9s
# Downloaded: 1 files, 609K in 0.04s (14.3 MB/s)
# Archive:  data_U5.zip
#    creating: transcripts/
#   inflating: transcripts/VLOG366.txt
#   inflating: transcripts/VLOG379.txt
#   inflating: transcripts/VLOG403.txt
#   inflating: transcripts/VLOG315.txt
#   inflating: transcripts/VLOG343.txt
#   inflating: transcripts/VLOG426.txt
#   inflating: transcripts/VLOG389.txt
#   inflating: transcripts/VLOG428.txt
#   inflating: transcripts/VLOG420.txt
#   inflating: transcripts/VLOG401.txt
#   inflating: transcripts/VLOG336.txt
#   inflating: transcripts/VLOG402.txt
#   inflating: transcripts/VLOG352.txt
#   inflating: transcripts/VLOG387.txt
#   inflating: transcripts/VLOG398.txt
#   inflating: transcripts/VLOG386.txt
#   inflating: transcripts/VLOG391.txt
#   inflating: transcripts/VLOG47.txt
#   inflating: transcripts/VLOG434.txt
#   inflating: transcripts/VLOG7.txt
#   inflating: transcripts/VLOG410.txt
#   inflating: transcripts/VLOG388.txt
#   inflating: transcripts/VLOG48.txt
#   inflating: transcripts/VLOG53.txt
#   inflating: transcripts/VLOG433.txt
#   inflating: transcripts/VLOG334.txt
#   inflating: transcripts/VLOG330.txt
#   inflating: transcripts/VLOG337.txt
#   inflating: transcripts/VLOG68.txt
#   inflating: transcripts/VLOG439.txt
#   inflating: transcripts/VLOG415.txt
#   inflating: transcripts/VLOG344.txt
#   inflating: transcripts/VLOG61.txt
#   inflating: transcripts/VLOG392.txt
#   inflating: transcripts/VLOG304.txt
#   inflating: transcripts/VLOG369.txt
#   inflating: transcripts/VLOG377.txt
#   inflating: transcripts/VLOG300.txt
#   inflating: transcripts/VLOG332.txt
#   inflating: transcripts/VLOG6.txt
#   inflating: transcripts/VLOG55.txt
#   inflating: transcripts/VLOG326.txt
#   inflating: transcripts/VLOG339.txt
#   inflating: transcripts/VLOG430.txt
#   inflating: transcripts/VLOG370.txt
#   inflating: transcripts/VLOG424.txt
#   inflating: transcripts/VLOG50.txt
#   inflating: transcripts/VLOG310.txt
#   inflating: transcripts/VLOG64.txt
#   inflating: transcripts/VLOG5.txt
#   inflating: transcripts/VLOG409.txt
#   inflating: transcripts/VLOG427.txt
#   inflating: transcripts/VLOG311.txt
#   inflating: transcripts/VLOG33.txt
#   inflating: transcripts/VLOG393.txt
#   inflating: transcripts/VLOG384.txt
#   inflating: transcripts/VLOG314.txt
#   inflating: transcripts/VLOG382.txt
#   inflating: transcripts/VLOG65.txt
#   inflating: transcripts/VLOG416.txt
#   inflating: transcripts/VLOG396.txt
#   inflating: transcripts/VLOG312.txt
#   inflating: transcripts/VLOG43.txt
#   inflating: transcripts/VLOG308.txt
#   inflating: transcripts/VLOG435.txt
#   inflating: transcripts/VLOG423.txt
#   inflating: transcripts/VLOG31.txt
#   inflating: transcripts/VLOG306.txt
#   inflating: transcripts/VLOG318.txt
#   inflating: transcripts/VLOG408.txt
#   inflating: transcripts/VLOG63.txt
#   inflating: transcripts/VLOG418.txt
#   inflating: transcripts/VLOG320.txt
#   inflating: transcripts/VLOG368.txt
#   inflating: transcripts/VLOG374.txt
#   inflating: transcripts/VLOG321.txt
#   inflating: transcripts/VLOG399.txt
#   inflating: transcripts/VLOG37.txt
#   inflating: transcripts/VLOG331.txt
#   inflating: transcripts/VLOG390.txt
#   inflating: transcripts/VLOG395.txt
#   inflating: transcripts/VLOG359.txt
#   inflating: transcripts/VLOG347.txt
#   inflating: transcripts/VLOG35.txt
#   inflating: transcripts/VLOG69.txt
#   inflating: transcripts/VLOG71.txt
#   inflating: transcripts/VLOG440.txt
#   inflating: transcripts/VLOG431.txt
#   inflating: transcripts/VLOG335.txt
#   inflating: transcripts/VLOG360.txt
#   inflating: transcripts/VLOG442.txt
#   inflating: transcripts/VLOG72.txt
#   inflating: transcripts/VLOG406.txt
#   inflating: transcripts/VLOG74.txt
#   inflating: transcripts/VLOG375.txt
#   inflating: transcripts/VLOG324.txt
#   inflating: transcripts/VLOG305.txt
#   inflating: transcripts/VLOG58.txt
#   inflating: transcripts/VLOG432.txt
#   inflating: transcripts/VLOG422.txt
#   inflating: transcripts/VLOG66.txt
#   inflating: transcripts/VLOG99.txt
#   inflating: transcripts/VLOG411.txt
#   inflating: transcripts/VLOG67.txt
#   inflating: transcripts/VLOG98.txt
#   inflating: transcripts/VLOG90.txt
#   inflating: transcripts/VLOG77.txt
#   inflating: transcripts/VLOG9.txt
#   inflating: transcripts/VLOG94.txt
#   inflating: transcripts/VLOG86.txt
#   inflating: transcripts/VLOG81.txt
#   inflating: transcripts/VLOG76.txt
#   inflating: transcripts/VLOG83.txt
#   inflating: transcripts/VLOG97.txt
#   inflating: transcripts/VLOG92.txt
#   inflating: transcripts/VLOG91.txt
#   inflating: transcripts/VLOG87.txt
#   inflating: transcripts/VLOG93.txt
#   inflating: transcripts/VLOG79.txt
#   inflating: transcripts/VLOG78.txt
#   inflating: transcripts/VLOG84.txt
#   inflating: transcripts/VLOG75.txt
#   inflating: transcripts/VLOG88.txt
#   inflating: transcripts/VLOG80.txt
#   inflating: transcripts/VLOG8.txt
#   inflating: transcripts/VLOG96.txt
#   inflating: transcripts/VLOG89.txt
#   inflating: transcripts/VLOG1.txt
#   inflating: transcripts/VLOG191.txt
#   inflating: transcripts/VLOG193.txt
#   inflating: transcripts/VLOG277.txt
#   inflating: transcripts/VLOG209.txt
#   inflating: transcripts/VLOG137.txt
#   inflating: transcripts/VLOG153.txt
#   inflating: transcripts/VLOG19.txt
#   inflating: transcripts/VLOG237.txt
#   inflating: transcripts/VLOG271.txt
#   inflating: transcripts/VLOG38.txt
#   inflating: transcripts/VLOG151.txt
#   inflating: transcripts/VLOG176.txt
#   inflating: transcripts/VLOG165.txt
#   inflating: transcripts/VLOG236.txt
#   inflating: transcripts/VLOG261.txt
#   inflating: transcripts/VLOG132.txt
#   inflating: transcripts/VLOG267.txt
#   inflating: transcripts/VLOG159.txt
#   inflating: transcripts/VLOG131.txt
#   inflating: transcripts/VLOG175.txt
#   inflating: transcripts/VLOG234.txt
#   inflating: transcripts/VLOG21.txt
#   inflating: transcripts/VLOG15.txt
#   inflating: transcripts/VLOG18.txt
#   inflating: transcripts/VLOG118.txt
#   inflating: transcripts/VLOG117.txt
#   inflating: transcripts/VLOG249.txt
#   inflating: transcripts/VLOG269.txt
#   inflating: transcripts/VLOG221.txt
#   inflating: transcripts/VLOG167.txt
#   inflating: transcripts/VLOG204.txt
#   inflating: transcripts/VLOG100.txt
#   inflating: transcripts/VLOG256.txt
#   inflating: transcripts/VLOG29.txt
#   inflating: transcripts/VLOG259.txt
#   inflating: transcripts/VLOG227.txt
#   inflating: transcripts/VLOG154.txt
#   inflating: transcripts/VLOG42.txt
#   inflating: transcripts/VLOG438.txt
#   inflating: transcripts/VLOG174.txt
#   inflating: transcripts/VLOG275.txt
#   inflating: transcripts/VLOG413.txt
#   inflating: transcripts/VLOG108.txt
#   inflating: transcripts/VLOG194.txt
#   inflating: transcripts/VLOG291.txt
#   inflating: transcripts/VLOG255.txt
#   inflating: transcripts/VLOG417.txt
#   inflating: transcripts/VLOG32.txt
#   inflating: transcripts/VLOG297.txt
#   inflating: transcripts/VLOG250.txt
#   inflating: transcripts/VLOG327.txt
#   inflating: transcripts/VLOG22.txt
#   inflating: transcripts/VLOG210.txt
#   inflating: transcripts/VLOG109.txt
#   inflating: transcripts/VLOG260.txt
#   inflating: transcripts/VLOG224.txt
#   inflating: transcripts/VLOG287.txt
#   inflating: transcripts/VLOG284.txt
#   inflating: transcripts/VLOG3.txt
#   inflating: transcripts/VLOG293.txt
#   inflating: transcripts/VLOG294.txt
#   inflating: transcripts/VLOG303.txt
#   inflating: transcripts/VLOG288.txt
#   inflating: transcripts/VLOG285.txt
#   inflating: transcripts/VLOG289.txt
#   inflating: transcripts/VLOG295.txt
#   inflating: transcripts/VLOG30.txt
#   inflating: transcripts/VLOG299.txt
#   inflating: transcripts/VLOG302.txt
#   inflating: transcripts/VLOG301.txt
#   inflating: transcripts/VLOG298.txt
#   inflating: transcripts/VLOG296.txt
#   inflating: transcripts/VLOG361.txt
#   inflating: transcripts/VLOG378.txt
#   inflating: transcripts/VLOG309.txt
#   inflating: transcripts/VLOG328.txt
#   inflating: transcripts/VLOG419.txt
#   inflating: transcripts/VLOG319.txt
#   inflating: transcripts/VLOG363.txt
#   inflating: transcripts/VLOG441.txt
#   inflating: transcripts/VLOG333.txt
#   inflating: transcripts/VLOG322.txt
#   inflating: transcripts/VLOG49.txt
#   inflating: transcripts/VLOG407.txt
#   inflating: transcripts/VLOG412.txt
#   inflating: transcripts/VLOG62.txt
#   inflating: transcripts/VLOG400.txt
#   inflating: transcripts/VLOG371.txt
#   inflating: transcripts/VLOG340.txt
#   inflating: transcripts/VLOG381.txt
#   inflating: transcripts/VLOG329.txt
#   inflating: transcripts/VLOG425.txt
#   inflating: transcripts/VLOG373.txt
#   inflating: transcripts/VLOG348.txt
#   inflating: transcripts/VLOG358.txt
#   inflating: transcripts/VLOG57.txt
#   inflating: transcripts/VLOG73.txt
#   inflating: transcripts/VLOG351.txt
#   inflating: transcripts/VLOG325.txt
#   inflating: transcripts/VLOG394.txt
#   inflating: transcripts/VLOG364.txt
#   inflating: transcripts/VLOG357.txt
#   inflating: transcripts/VLOG44.txt
#   inflating: transcripts/VLOG437.txt
#   inflating: transcripts/VLOG350.txt
#   inflating: transcripts/VLOG36.txt
#   inflating: transcripts/VLOG54.txt
#   inflating: transcripts/VLOG414.txt
#   inflating: transcripts/VLOG39.txt
#   inflating: transcripts/VLOG365.txt
#   inflating: transcripts/VLOG346.txt
#   inflating: transcripts/VLOG405.txt
#   inflating: transcripts/VLOG46.txt
#   inflating: transcripts/VLOG70.txt
#   inflating: transcripts/VLOG338.txt
#   inflating: transcripts/VLOG397.txt
#   inflating: transcripts/VLOG345.txt
#   inflating: transcripts/VLOG421.txt
#   inflating: transcripts/VLOG341.txt
#   inflating: transcripts/VLOG52.txt
#   inflating: transcripts/VLOG367.txt
#   inflating: transcripts/VLOG60.txt
#   inflating: transcripts/VLOG313.txt
#   inflating: transcripts/VLOG353.txt
#   inflating: transcripts/VLOG355.txt
#   inflating: transcripts/VLOG380.txt
#   inflating: transcripts/VLOG51.txt
#   inflating: transcripts/VLOG372.txt
#   inflating: transcripts/VLOG124.txt
#   inflating: transcripts/VLOG16.txt
#   inflating: transcripts/VLOG129.txt
#   inflating: transcripts/VLOG278.txt
#   inflating: transcripts/VLOG220.txt
#   inflating: transcripts/VLOG155.txt
#   inflating: transcripts/VLOG158.txt
#   inflating: transcripts/VLOG168.txt
#   inflating: transcripts/VLOG235.txt
#   inflating: transcripts/VLOG279.txt
#   inflating: transcripts/VLOG103.txt
#   inflating: transcripts/VLOG248.txt
#   inflating: transcripts/VLOG436.txt
#   inflating: transcripts/VLOG160.txt
#   inflating: transcripts/VLOG216.txt
#   inflating: transcripts/VLOG126.txt
#   inflating: transcripts/VLOG104.txt
#   inflating: transcripts/VLOG232.txt
#   inflating: transcripts/VLOG214.txt
#   inflating: transcripts/VLOG228.txt
#   inflating: transcripts/VLOG192.txt
#   inflating: transcripts/VLOG239.txt
#   inflating: transcripts/VLOG14.txt
#   inflating: transcripts/VLOG222.txt
#   inflating: transcripts/VLOG27.txt
#   inflating: transcripts/VLOG123.txt
#   inflating: transcripts/VLOG140.txt
#   inflating: transcripts/VLOG207.txt
#   inflating: transcripts/VLOG28.txt
#   inflating: transcripts/VLOG233.txt
#   inflating: transcripts/VLOG181.txt
#   inflating: transcripts/VLOG187.txt
#   inflating: transcripts/VLOG150.txt
#   inflating: transcripts/VLOG205.txt
#   inflating: transcripts/VLOG282.txt
#   inflating: transcripts/VLOG213.txt
#   inflating: transcripts/VLOG13.txt
#   inflating: transcripts/VLOG202.txt
#   inflating: transcripts/VLOG272.txt
#   inflating: transcripts/VLOG162.txt
#   inflating: transcripts/VLOG186.txt
#   inflating: transcripts/VLOG247.txt
#   inflating: transcripts/VLOG120.txt
#   inflating: transcripts/VLOG12.txt
#   inflating: transcripts/VLOG198.txt
#   inflating: transcripts/VLOG199.txt
#   inflating: transcripts/VLOG253.txt
#   inflating: transcripts/VLOG138.txt
#   inflating: transcripts/VLOG292.txt
#   inflating: transcripts/VLOG119.txt
#   inflating: transcripts/VLOG270.txt
#   inflating: transcripts/VLOG134.txt
#   inflating: transcripts/VLOG180.txt
#   inflating: transcripts/VLOG276.txt
#   inflating: transcripts/VLOG164.txt
#   inflating: transcripts/VLOG148.txt
#   inflating: transcripts/VLOG141.txt
#   inflating: transcripts/VLOG11.txt
#   inflating: transcripts/VLOG281.txt
#   inflating: transcripts/VLOG135.txt
#   inflating: transcripts/VLOG144.txt
#   inflating: transcripts/VLOG149.txt
#   inflating: transcripts/VLOG170.txt
#   inflating: transcripts/VLOG226.txt
#   inflating: transcripts/VLOG114.txt
#   inflating: transcripts/VLOG163.txt
#   inflating: transcripts/VLOG152.txt
#   inflating: transcripts/VLOG323.txt
#   inflating: transcripts/VLOG189.txt
#   inflating: transcripts/VLOG116.txt
#   inflating: transcripts/VLOG105.txt
#   inflating: transcripts/VLOG24.txt
#   inflating: transcripts/VLOG182.txt
#   inflating: transcripts/VLOG274.txt
#   inflating: transcripts/VLOG190.txt
#   inflating: transcripts/VLOG178.txt
#   inflating: transcripts/VLOG45.txt
#   inflating: transcripts/VLOG196.txt
#   inflating: transcripts/VLOG264.txt
#   inflating: transcripts/VLOG171.txt
#   inflating: transcripts/VLOG125.txt
#   inflating: transcripts/VLOG145.txt
#   inflating: transcripts/VLOG251.txt
#   inflating: transcripts/VLOG106.txt
#   inflating: transcripts/VLOG169.txt
#   inflating: transcripts/VLOG404.txt
#   inflating: transcripts/VLOG280.txt
#   inflating: transcripts/VLOG257.txt
#   inflating: transcripts/VLOG266.txt
#   inflating: transcripts/VLOG25.txt
#   inflating: transcripts/VLOG246.txt
#   inflating: transcripts/VLOG283.txt
#   inflating: transcripts/VLOG59.txt
#   inflating: transcripts/VLOG26.txt
#   inflating: transcripts/VLOG184.txt
#   inflating: transcripts/VLOG10.txt
#   inflating: transcripts/VLOG156.txt
#   inflating: transcripts/VLOG225.txt
#   inflating: transcripts/VLOG219.txt
#   inflating: transcripts/VLOG147.txt
#   inflating: transcripts/VLOG244.txt
#   inflating: transcripts/VLOG166.txt
#   inflating: transcripts/VLOG317.txt
#   inflating: transcripts/VLOG218.txt
#   inflating: transcripts/VLOG17.txt
#   inflating: transcripts/VLOG146.txt
#   inflating: transcripts/VLOG142.txt
#   inflating: transcripts/VLOG268.txt
#   inflating: transcripts/VLOG161.txt
#   inflating: transcripts/VLOG286.txt
#   inflating: transcripts/VLOG273.txt
#   inflating: transcripts/VLOG183.txt
#   inflating: transcripts/VLOG23.txt
#   inflating: transcripts/VLOG201.txt
#   inflating: transcripts/VLOG130.txt
#   inflating: transcripts/VLOG136.txt
#   inflating: transcripts/VLOG252.txt
#   inflating: transcripts/VLOG110.txt
#   inflating: transcripts/VLOG241.txt
#   inflating: transcripts/VLOG173.txt
#   inflating: transcripts/VLOG242.txt
#   inflating: transcripts/VLOG265.txt
#   inflating: transcripts/VLOG111.txt
#   inflating: transcripts/VLOG385.txt
#   inflating: transcripts/VLOG263.txt
#   inflating: transcripts/VLOG112.txt
#   inflating: transcripts/VLOG307.txt
#   inflating: transcripts/VLOG113.txt
#   inflating: transcripts/VLOG102.txt
#   inflating: transcripts/VLOG197.txt
#   inflating: transcripts/VLOG122.txt
#   inflating: transcripts/VLOG195.txt
#   inflating: transcripts/VLOG217.txt
#   inflating: transcripts/VLOG143.txt
#   inflating: transcripts/VLOG107.txt
#   inflating: transcripts/VLOG223.txt
#   inflating: transcripts/VLOG172.txt
#   inflating: transcripts/VLOG56.txt
#   inflating: transcripts/VLOG262.txt
#   inflating: transcripts/VLOG229.txt
#   inflating: transcripts/VLOG212.txt
#   inflating: transcripts/VLOG376.txt
#   inflating: transcripts/VLOG290.txt
#   inflating: transcripts/VLOG254.txt
#   inflating: transcripts/VLOG243.txt
#   inflating: transcripts/VLOG179.txt
#   inflating: transcripts/VLOG127.txt
#   inflating: transcripts/VLOG133.txt
#   inflating: Labels.csv
#   inflating: LabelsClassification.csv

# %%
from time import time
import numpy as np
import matplotlib.pyplot as plt
import os #Interfaz Python-Sistema Operativo

#%%

#Function to preprocess the data
def preprocess(text):
    #text = toLowerCase(text)
    
    text = muletsRemoval(text)
    
    text = noPunctuation(text)

    text = noPunctuationExtra(text)
    
    text = removeNumbers(text)

    #text = StopWordsRemoval(text)

    #text = Lemmatizer(text)
    
    text = CleanText(text)
    return text

#%%
# LOAD DATA
route='./transcripts/'
file_list = os.listdir(route) 
file_list.sort()

#%%
#Preprocess data
start_time = time()
print(start_time)
print("--"*20+"Preprocessing starts"+"--"*20)


texts_preprocessed=[]

for file in file_list:
    text = (open(route+file)).read()
    text = " ".join(text.split())
    text_pre = preprocess(text)
    text_pre = " ".join(text_pre.split())#Para remover espacios blancos indeseados
    texts_preprocessed.append(text_pre)
    print("--"*10+ file+" Ready"+"--"*10)

print("--"*20+"Preprocessing ends"+"--"*20)

elapsed_time = time() - start_time
print("Tiempo tomado para preprocesar: %0.10f seconds." % elapsed_time)
# Out:
# 1591654832.162573
# ----------------------------------------Preprocessing starts----------------------------------------
# --------------------VLOG1.txt Ready--------------------
# --------------------VLOG10.txt Ready--------------------
# --------------------VLOG100.txt Ready--------------------
# --------------------VLOG102.txt Ready--------------------
# --------------------VLOG103.txt Ready--------------------
# --------------------VLOG104.txt Ready--------------------
# --------------------VLOG105.txt Ready--------------------
# --------------------VLOG106.txt Ready--------------------
# --------------------VLOG107.txt Ready--------------------
# --------------------VLOG108.txt Ready--------------------
# --------------------VLOG109.txt Ready--------------------
# --------------------VLOG11.txt Ready--------------------
# --------------------VLOG110.txt Ready--------------------
# --------------------VLOG111.txt Ready--------------------
# --------------------VLOG112.txt Ready--------------------
# --------------------VLOG113.txt Ready--------------------
# --------------------VLOG114.txt Ready--------------------
# --------------------VLOG116.txt Ready--------------------
# --------------------VLOG117.txt Ready--------------------
# --------------------VLOG118.txt Ready--------------------
# --------------------VLOG119.txt Ready--------------------
# --------------------VLOG12.txt Ready--------------------
# --------------------VLOG120.txt Ready--------------------
# --------------------VLOG122.txt Ready--------------------
# --------------------VLOG123.txt Ready--------------------
# --------------------VLOG124.txt Ready--------------------
# --------------------VLOG125.txt Ready--------------------
# --------------------VLOG126.txt Ready--------------------
# --------------------VLOG127.txt Ready--------------------
# --------------------VLOG129.txt Ready--------------------
# --------------------VLOG13.txt Ready--------------------
# --------------------VLOG130.txt Ready--------------------
# --------------------VLOG131.txt Ready--------------------
# --------------------VLOG132.txt Ready--------------------
# --------------------VLOG133.txt Ready--------------------
# --------------------VLOG134.txt Ready--------------------
# --------------------VLOG135.txt Ready--------------------
# --------------------VLOG136.txt Ready--------------------
# --------------------VLOG137.txt Ready--------------------
# --------------------VLOG138.txt Ready--------------------
# --------------------VLOG14.txt Ready--------------------
# --------------------VLOG140.txt Ready--------------------
# --------------------VLOG141.txt Ready--------------------
# --------------------VLOG142.txt Ready--------------------
# --------------------VLOG143.txt Ready--------------------
# --------------------VLOG144.txt Ready--------------------
# --------------------VLOG145.txt Ready--------------------
# --------------------VLOG146.txt Ready--------------------
# --------------------VLOG147.txt Ready--------------------
# --------------------VLOG148.txt Ready--------------------
# --------------------VLOG149.txt Ready--------------------
# --------------------VLOG15.txt Ready--------------------
# --------------------VLOG150.txt Ready--------------------
# --------------------VLOG151.txt Ready--------------------
# --------------------VLOG152.txt Ready--------------------
# --------------------VLOG153.txt Ready--------------------
# --------------------VLOG154.txt Ready--------------------
# --------------------VLOG155.txt Ready--------------------
# --------------------VLOG156.txt Ready--------------------
# --------------------VLOG158.txt Ready--------------------
# --------------------VLOG159.txt Ready--------------------
# --------------------VLOG16.txt Ready--------------------
# --------------------VLOG160.txt Ready--------------------
# --------------------VLOG161.txt Ready--------------------
# --------------------VLOG162.txt Ready--------------------
# --------------------VLOG163.txt Ready--------------------
# --------------------VLOG164.txt Ready--------------------
# --------------------VLOG165.txt Ready--------------------
# --------------------VLOG166.txt Ready--------------------
# --------------------VLOG167.txt Ready--------------------
# --------------------VLOG168.txt Ready--------------------
# --------------------VLOG169.txt Ready--------------------
# --------------------VLOG17.txt Ready--------------------
# --------------------VLOG170.txt Ready--------------------
# --------------------VLOG171.txt Ready--------------------
# --------------------VLOG172.txt Ready--------------------
# --------------------VLOG173.txt Ready--------------------
# --------------------VLOG174.txt Ready--------------------
# --------------------VLOG175.txt Ready--------------------
# --------------------VLOG176.txt Ready--------------------
# --------------------VLOG178.txt Ready--------------------
# --------------------VLOG179.txt Ready--------------------
# --------------------VLOG18.txt Ready--------------------
# --------------------VLOG180.txt Ready--------------------
# --------------------VLOG181.txt Ready--------------------
# --------------------VLOG182.txt Ready--------------------
# --------------------VLOG183.txt Ready--------------------
# --------------------VLOG184.txt Ready--------------------
# --------------------VLOG186.txt Ready--------------------
# --------------------VLOG187.txt Ready--------------------
# --------------------VLOG189.txt Ready--------------------
# --------------------VLOG19.txt Ready--------------------
# --------------------VLOG190.txt Ready--------------------
# --------------------VLOG191.txt Ready--------------------
# --------------------VLOG192.txt Ready--------------------
# --------------------VLOG193.txt Ready--------------------
# --------------------VLOG194.txt Ready--------------------
# --------------------VLOG195.txt Ready--------------------
# --------------------VLOG196.txt Ready--------------------
# --------------------VLOG197.txt Ready--------------------
# --------------------VLOG198.txt Ready--------------------
# --------------------VLOG199.txt Ready--------------------
# --------------------VLOG201.txt Ready--------------------
# --------------------VLOG202.txt Ready--------------------
# --------------------VLOG204.txt Ready--------------------
# --------------------VLOG205.txt Ready--------------------
# --------------------VLOG207.txt Ready--------------------
# --------------------VLOG209.txt Ready--------------------
# --------------------VLOG21.txt Ready--------------------
# --------------------VLOG210.txt Ready--------------------
# --------------------VLOG212.txt Ready--------------------
# --------------------VLOG213.txt Ready--------------------
# --------------------VLOG214.txt Ready--------------------
# --------------------VLOG216.txt Ready--------------------
# --------------------VLOG217.txt Ready--------------------
# --------------------VLOG218.txt Ready--------------------
# --------------------VLOG219.txt Ready--------------------
# --------------------VLOG22.txt Ready--------------------
# --------------------VLOG220.txt Ready--------------------
# --------------------VLOG221.txt Ready--------------------
# --------------------VLOG222.txt Ready--------------------
# --------------------VLOG223.txt Ready--------------------
# --------------------VLOG224.txt Ready--------------------
# --------------------VLOG225.txt Ready--------------------
# --------------------VLOG226.txt Ready--------------------
# --------------------VLOG227.txt Ready--------------------
# --------------------VLOG228.txt Ready--------------------
# --------------------VLOG229.txt Ready--------------------
# --------------------VLOG23.txt Ready--------------------
# --------------------VLOG232.txt Ready--------------------
# --------------------VLOG233.txt Ready--------------------
# --------------------VLOG234.txt Ready--------------------
# --------------------VLOG235.txt Ready--------------------
# --------------------VLOG236.txt Ready--------------------
# --------------------VLOG237.txt Ready--------------------
# --------------------VLOG239.txt Ready--------------------
# --------------------VLOG24.txt Ready--------------------
# --------------------VLOG241.txt Ready--------------------
# --------------------VLOG242.txt Ready--------------------
# --------------------VLOG243.txt Ready--------------------
# --------------------VLOG244.txt Ready--------------------
# --------------------VLOG246.txt Ready--------------------
# --------------------VLOG247.txt Ready--------------------
# --------------------VLOG248.txt Ready--------------------
# --------------------VLOG249.txt Ready--------------------
# --------------------VLOG25.txt Ready--------------------
# --------------------VLOG250.txt Ready--------------------
# --------------------VLOG251.txt Ready--------------------
# --------------------VLOG252.txt Ready--------------------
# --------------------VLOG253.txt Ready--------------------
# --------------------VLOG254.txt Ready--------------------
# --------------------VLOG255.txt Ready--------------------
# --------------------VLOG256.txt Ready--------------------
# --------------------VLOG257.txt Ready--------------------
# --------------------VLOG259.txt Ready--------------------
# --------------------VLOG26.txt Ready--------------------
# --------------------VLOG260.txt Ready--------------------
# --------------------VLOG261.txt Ready--------------------
# --------------------VLOG262.txt Ready--------------------
# --------------------VLOG263.txt Ready--------------------
# --------------------VLOG264.txt Ready--------------------
# --------------------VLOG265.txt Ready--------------------
# --------------------VLOG266.txt Ready--------------------
# --------------------VLOG267.txt Ready--------------------
# --------------------VLOG268.txt Ready--------------------
# --------------------VLOG269.txt Ready--------------------
# --------------------VLOG27.txt Ready--------------------
# --------------------VLOG270.txt Ready--------------------
# --------------------VLOG271.txt Ready--------------------
# --------------------VLOG272.txt Ready--------------------
# --------------------VLOG273.txt Ready--------------------
# --------------------VLOG274.txt Ready--------------------
# --------------------VLOG275.txt Ready--------------------
# --------------------VLOG276.txt Ready--------------------
# --------------------VLOG277.txt Ready--------------------
# --------------------VLOG278.txt Ready--------------------
# --------------------VLOG279.txt Ready--------------------
# --------------------VLOG28.txt Ready--------------------
# --------------------VLOG280.txt Ready--------------------
# --------------------VLOG281.txt Ready--------------------
# --------------------VLOG282.txt Ready--------------------
# --------------------VLOG283.txt Ready--------------------
# --------------------VLOG284.txt Ready--------------------
# --------------------VLOG285.txt Ready--------------------
# --------------------VLOG286.txt Ready--------------------
# --------------------VLOG287.txt Ready--------------------
# --------------------VLOG288.txt Ready--------------------
# --------------------VLOG289.txt Ready--------------------
# --------------------VLOG29.txt Ready--------------------
# --------------------VLOG290.txt Ready--------------------
# --------------------VLOG291.txt Ready--------------------
# --------------------VLOG292.txt Ready--------------------
# --------------------VLOG293.txt Ready--------------------
# --------------------VLOG294.txt Ready--------------------
# --------------------VLOG295.txt Ready--------------------
# --------------------VLOG296.txt Ready--------------------
# --------------------VLOG297.txt Ready--------------------
# --------------------VLOG298.txt Ready--------------------
# --------------------VLOG299.txt Ready--------------------
# --------------------VLOG3.txt Ready--------------------
# --------------------VLOG30.txt Ready--------------------
# --------------------VLOG300.txt Ready--------------------
# --------------------VLOG301.txt Ready--------------------
# --------------------VLOG302.txt Ready--------------------
# --------------------VLOG303.txt Ready--------------------
# --------------------VLOG304.txt Ready--------------------
# --------------------VLOG305.txt Ready--------------------
# --------------------VLOG306.txt Ready--------------------
# --------------------VLOG307.txt Ready--------------------
# --------------------VLOG308.txt Ready--------------------
# --------------------VLOG309.txt Ready--------------------
# --------------------VLOG31.txt Ready--------------------
# --------------------VLOG310.txt Ready--------------------
# --------------------VLOG311.txt Ready--------------------
# --------------------VLOG312.txt Ready--------------------
# --------------------VLOG313.txt Ready--------------------
# --------------------VLOG314.txt Ready--------------------
# --------------------VLOG315.txt Ready--------------------
# --------------------VLOG317.txt Ready--------------------
# --------------------VLOG318.txt Ready--------------------
# --------------------VLOG319.txt Ready--------------------
# --------------------VLOG32.txt Ready--------------------
# --------------------VLOG320.txt Ready--------------------
# --------------------VLOG321.txt Ready--------------------
# --------------------VLOG322.txt Ready--------------------
# --------------------VLOG323.txt Ready--------------------
# --------------------VLOG324.txt Ready--------------------
# --------------------VLOG325.txt Ready--------------------
# --------------------VLOG326.txt Ready--------------------
# --------------------VLOG327.txt Ready--------------------
# --------------------VLOG328.txt Ready--------------------
# --------------------VLOG329.txt Ready--------------------
# --------------------VLOG33.txt Ready--------------------
# --------------------VLOG330.txt Ready--------------------
# --------------------VLOG331.txt Ready--------------------
# --------------------VLOG332.txt Ready--------------------
# --------------------VLOG333.txt Ready--------------------
# --------------------VLOG334.txt Ready--------------------
# --------------------VLOG335.txt Ready--------------------
# --------------------VLOG336.txt Ready--------------------
# --------------------VLOG337.txt Ready--------------------
# --------------------VLOG338.txt Ready--------------------
# --------------------VLOG339.txt Ready--------------------
# --------------------VLOG340.txt Ready--------------------
# --------------------VLOG341.txt Ready--------------------
# --------------------VLOG343.txt Ready--------------------
# --------------------VLOG344.txt Ready--------------------
# --------------------VLOG345.txt Ready--------------------
# --------------------VLOG346.txt Ready--------------------
# --------------------VLOG347.txt Ready--------------------
# --------------------VLOG348.txt Ready--------------------
# --------------------VLOG35.txt Ready--------------------
# --------------------VLOG350.txt Ready--------------------
# --------------------VLOG351.txt Ready--------------------
# --------------------VLOG352.txt Ready--------------------
# --------------------VLOG353.txt Ready--------------------
# --------------------VLOG355.txt Ready--------------------
# --------------------VLOG357.txt Ready--------------------
# --------------------VLOG358.txt Ready--------------------
# --------------------VLOG359.txt Ready--------------------
# --------------------VLOG36.txt Ready--------------------
# --------------------VLOG360.txt Ready--------------------
# --------------------VLOG361.txt Ready--------------------
# --------------------VLOG363.txt Ready--------------------
# --------------------VLOG364.txt Ready--------------------
# --------------------VLOG365.txt Ready--------------------
# --------------------VLOG366.txt Ready--------------------
# --------------------VLOG367.txt Ready--------------------
# --------------------VLOG368.txt Ready--------------------
# --------------------VLOG369.txt Ready--------------------
# --------------------VLOG37.txt Ready--------------------
# --------------------VLOG370.txt Ready--------------------
# --------------------VLOG371.txt Ready--------------------
# --------------------VLOG372.txt Ready--------------------
# --------------------VLOG373.txt Ready--------------------
# --------------------VLOG374.txt Ready--------------------
# --------------------VLOG375.txt Ready--------------------
# --------------------VLOG376.txt Ready--------------------
# --------------------VLOG377.txt Ready--------------------
# --------------------VLOG378.txt Ready--------------------
# --------------------VLOG379.txt Ready--------------------
# --------------------VLOG38.txt Ready--------------------
# --------------------VLOG380.txt Ready--------------------
# --------------------VLOG381.txt Ready--------------------
# --------------------VLOG382.txt Ready--------------------
# --------------------VLOG384.txt Ready--------------------
# --------------------VLOG385.txt Ready--------------------
# --------------------VLOG386.txt Ready--------------------
# --------------------VLOG387.txt Ready--------------------
# --------------------VLOG388.txt Ready--------------------
# --------------------VLOG389.txt Ready--------------------
# --------------------VLOG39.txt Ready--------------------
# --------------------VLOG390.txt Ready--------------------
# --------------------VLOG391.txt Ready--------------------
# --------------------VLOG392.txt Ready--------------------
# --------------------VLOG393.txt Ready--------------------
# --------------------VLOG394.txt Ready--------------------
# --------------------VLOG395.txt Ready--------------------
# --------------------VLOG396.txt Ready--------------------
# --------------------VLOG397.txt Ready--------------------
# --------------------VLOG398.txt Ready--------------------
# --------------------VLOG399.txt Ready--------------------
# --------------------VLOG400.txt Ready--------------------
# --------------------VLOG401.txt Ready--------------------
# --------------------VLOG402.txt Ready--------------------
# --------------------VLOG403.txt Ready--------------------
# --------------------VLOG404.txt Ready--------------------
# --------------------VLOG405.txt Ready--------------------
# --------------------VLOG406.txt Ready--------------------
# --------------------VLOG407.txt Ready--------------------
# --------------------VLOG408.txt Ready--------------------
# --------------------VLOG409.txt Ready--------------------
# --------------------VLOG410.txt Ready--------------------
# --------------------VLOG411.txt Ready--------------------
# --------------------VLOG412.txt Ready--------------------
# --------------------VLOG413.txt Ready--------------------
# --------------------VLOG414.txt Ready--------------------
# --------------------VLOG415.txt Ready--------------------
# --------------------VLOG416.txt Ready--------------------
# --------------------VLOG417.txt Ready--------------------
# --------------------VLOG418.txt Ready--------------------
# --------------------VLOG419.txt Ready--------------------
# --------------------VLOG42.txt Ready--------------------
# --------------------VLOG420.txt Ready--------------------
# --------------------VLOG421.txt Ready--------------------
# --------------------VLOG422.txt Ready--------------------
# --------------------VLOG423.txt Ready--------------------
# --------------------VLOG424.txt Ready--------------------
# --------------------VLOG425.txt Ready--------------------
# --------------------VLOG426.txt Ready--------------------
# --------------------VLOG427.txt Ready--------------------
# --------------------VLOG428.txt Ready--------------------
# --------------------VLOG43.txt Ready--------------------
# --------------------VLOG430.txt Ready--------------------
# --------------------VLOG431.txt Ready--------------------
# --------------------VLOG432.txt Ready--------------------
# --------------------VLOG433.txt Ready--------------------
# --------------------VLOG434.txt Ready--------------------
# --------------------VLOG435.txt Ready--------------------
# --------------------VLOG436.txt Ready--------------------
# --------------------VLOG437.txt Ready--------------------
# --------------------VLOG438.txt Ready--------------------
# --------------------VLOG439.txt Ready--------------------
# --------------------VLOG44.txt Ready--------------------
# --------------------VLOG440.txt Ready--------------------
# --------------------VLOG441.txt Ready--------------------
# --------------------VLOG442.txt Ready--------------------
# --------------------VLOG45.txt Ready--------------------
# --------------------VLOG46.txt Ready--------------------
# --------------------VLOG47.txt Ready--------------------
# --------------------VLOG48.txt Ready--------------------
# --------------------VLOG49.txt Ready--------------------
# --------------------VLOG5.txt Ready--------------------
# --------------------VLOG50.txt Ready--------------------
# --------------------VLOG51.txt Ready--------------------
# --------------------VLOG52.txt Ready--------------------
# --------------------VLOG53.txt Ready--------------------
# --------------------VLOG54.txt Ready--------------------
# --------------------VLOG55.txt Ready--------------------
# --------------------VLOG56.txt Ready--------------------
# --------------------VLOG57.txt Ready--------------------
# --------------------VLOG58.txt Ready--------------------
# --------------------VLOG59.txt Ready--------------------
# --------------------VLOG6.txt Ready--------------------
# --------------------VLOG60.txt Ready--------------------
# --------------------VLOG61.txt Ready--------------------
# --------------------VLOG62.txt Ready--------------------
# --------------------VLOG63.txt Ready--------------------
# --------------------VLOG64.txt Ready--------------------
# --------------------VLOG65.txt Ready--------------------
# --------------------VLOG66.txt Ready--------------------
# --------------------VLOG67.txt Ready--------------------
# --------------------VLOG68.txt Ready--------------------
# --------------------VLOG69.txt Ready--------------------
# --------------------VLOG7.txt Ready--------------------
# --------------------VLOG70.txt Ready--------------------
# --------------------VLOG71.txt Ready--------------------
# --------------------VLOG72.txt Ready--------------------
# --------------------VLOG73.txt Ready--------------------
# --------------------VLOG74.txt Ready--------------------
# --------------------VLOG75.txt Ready--------------------
# --------------------VLOG76.txt Ready--------------------
# --------------------VLOG77.txt Ready--------------------
# --------------------VLOG78.txt Ready--------------------
# --------------------VLOG79.txt Ready--------------------
# --------------------VLOG8.txt Ready--------------------
# --------------------VLOG80.txt Ready--------------------
# --------------------VLOG81.txt Ready--------------------
# --------------------VLOG83.txt Ready--------------------
# --------------------VLOG84.txt Ready--------------------
# --------------------VLOG86.txt Ready--------------------
# --------------------VLOG87.txt Ready--------------------
# --------------------VLOG88.txt Ready--------------------
# --------------------VLOG89.txt Ready--------------------
# --------------------VLOG9.txt Ready--------------------
# --------------------VLOG90.txt Ready--------------------
# --------------------VLOG91.txt Ready--------------------
# --------------------VLOG92.txt Ready--------------------
# --------------------VLOG93.txt Ready--------------------
# --------------------VLOG94.txt Ready--------------------
# --------------------VLOG96.txt Ready--------------------
# --------------------VLOG97.txt Ready--------------------
# --------------------VLOG98.txt Ready--------------------
# --------------------VLOG99.txt Ready--------------------
# ----------------------------------------Preprocessing ends----------------------------------------
# Tiempo tomado para preprocesar: 3.0165088177 seconds.

# %%
texts_preprocessed[4]
# Out:
# 'Hi its and this is just quick little update to let you know how Im doing went to retreat with the church last weekend and when got up there couldnt eat anything my dont know if it was like the altitude or like what but my band got really tight and couldnt eat anything When came back my weight was down to on seventy seven and then after couple of days of being home then my weight started to get back to normal but still couldnt eat so had to go back to see my surgeon and get little bit of food out of my band and they took out one cc putting me at four point two Everybody this is Im on my retreat right now got here last night It was it was dark when got here so came last year but this year came with the intentions of running in the mornings Well last night was all pumped looking to get up early this morning and run so get up early earlier than Id like to at least start running Before know it Im going downhill and suddenly Im going uphill Its cold and my Central Valley California self is evasive So wanted to do video and wanted to run Came back out of here to the little trail they out here in the neighborhood You can see me and just like the other part that was running on its all uphill and downhill and its raining Its muddy and its wet And Im not exactly sure where Im at But Im looking to stop walking at least dont think Im going to get any more running done Now brought my jump rope with me If had any brains in my head would go back and jump rope for however long til decided to pass out But now Im half way through this little adventure of mine It feels like Im going to die was thinking this is going to be breeze cause went to the gym only Ive been running mile you know and Ive been doing it under ten minutes feel like Im gonna die now seriously Breather really quick When get to the top because standing at an angle is no fun said the top and the more steps take the more higher it gets Geez So my sisters going to see this video posting and shes going to laugh at me Im really Ive got to stop If dont know if you can see down there Im pretty high mean way down there is the cars dont know if you could see them or not Ooh lets not fall off the side though Okay my cousin got up with me She said Lets go down to the showers and take showers and get ready for our day today want to run before take shower and shes just like What Shes like Well got flip flops on so Im not running with you swear saw sneakers in her bag though Rachel feel like Im gonna die Looks like Im almost there guys Looks like Im almost there have not breathed so hard in forever This uphill stuff is just not my thing Course didnt think it was uphill when started Looks like its going down guys Ive been walking the video says four minutes and fifty one seconds But turned it on half way through Im starting to make my way downhill Over there must have been the cabins And then okay Not sure what that is Dont look like kitchen Maybe these are the cabins Maybe found my way back to the cabins Should share my music Right this songs forty minutes long Lets see wheres my cabin should go wake everybody up dont think this is my cabin though think Im lost Ill do another later think Im lost right now in the woods in the rain and its wet Oh this is kind of weird Im like have to get in so guess Im going around again Okay well it was nice seeing you guys and Ill have to splice this video later All right bye'

# %%
import sys
if 'google.colab' in sys.modules:
    print ("setting tensorflow version in colab")
    # %tensorflow_version 1.x
import tensorflow as tf
tf.__version__
# Out:
# setting tensorflow version in colab
# TensorFlow 1.x selected.
# '1.15.2'

# %%
import tensorflow_hub as hub
import tensorflow as tf

# %%
# !pip install seqeval[cpu]
# Out:
# Collecting seqeval[cpu]
#   Downloading https://files.pythonhosted.org/packages/34/91/068aca8d60ce56dd9ba4506850e876aba5e66a6f2f29aa223224b50df0de/seqeval-0.0.12.tar.gz
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from seqeval[cpu]) (1.18.4)
# Requirement already satisfied: Keras>=2.2.4 in /usr/local/lib/python3.6/dist-packages (from seqeval[cpu]) (2.3.1)
# Requirement already satisfied: tensorflow>=1.13.1 in /tensorflow-1.15.2/python3.6 (from seqeval[cpu]) (1.15.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval[cpu]) (1.1.2)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->seqeval[cpu]) (3.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->seqeval[cpu]) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->seqeval[cpu]) (3.2.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->seqeval[cpu]) (1.12.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->seqeval[cpu]) (0.34.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->seqeval[cpu]) (0.8.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->seqeval[cpu]) (1.29.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /tensorflow-1.15.2/python3.6 (from tensorflow>=1.13.1->seqeval[cpu]) (1.15.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->seqeval[cpu]) (0.2.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /tensorflow-1.15.2/python3.6 (from tensorflow>=1.13.1->seqeval[cpu]) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.13.1->seqeval[cpu]) (0.9.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow>=1.13.1->seqeval[cpu]) (47.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow>=1.13.1->seqeval[cpu]) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow>=1.13.1->seqeval[cpu]) (3.2.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow>=1.13.1->seqeval[cpu]) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow>=1.13.1->seqeval[cpu]) (3.1.0)
# Building wheels for collected packages: seqeval, gast
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-0.0.12-cp36-none-any.whl size=7424 sha256=b29cb8d8797675d1d2218c98d6f211d8cc2a589a9eba4958ba948afe09faba91
#   Stored in directory: /root/.cache/pip/wheels/4f/32/0a/df3b340a82583566975377d65e724895b3fad101a3fb729f68
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=b86cbca4db99a6e7318f4e4ff527c2d9c4c4d28f9e24d3f94ea66c7243adc58d
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built seqeval gast
# Installing collected packages: seqeval, gast
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
# Successfully installed gast-0.2.2 seqeval-0.0.12

# %%
new_texts = []
for i in range(len(texts_preprocessed)):
  new_texts.append(texts_preprocessed[i].split(" "))

# %%
largest_sen = max(len(sen) for sen in new_texts)
print('biggest sentence has {} words'.format(largest_sen))
# Out:
# biggest sentence has 1886 words

# %%
# %matplotlib inline
plt.figure(figsize=(10,8))
plt.hist([len(sen) for sen in new_texts], bins= 50)
plt.xlabel('Number of words per text',fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.grid()
plt.tick_params(labelsize=18)
plt.savefig('Histogram.png')
plt.show()

# %% [markdown]
# ### Modify the following parameter to obtain results with different maximun number of words per text.

# %%
max_len = 300

# %%
import tensorflow as tf
import tensorflow_hub as hub
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# This is how we have to define the layer in order to be used in the model (In TF 2.x this should not be necessary [take a look to this guide](https://www.tensorflow.org/hub)):

# %%
from keras.models import Model, Input
from keras.layers.merge import add
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional, Lambda, add, Flatten, BatchNormalization
from keras.layers.merge import Concatenate
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip glove.6B.zip
# Out:
# --2020-06-08 20:52:31--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2020-06-08 20:52:31--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2020-06-08 20:52:32--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  2.11MB/s    in 6m 30s
#
# 2020-06-08 20:59:02 (2.11 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]
#
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

max_words = 5000

tokenizer = Tokenizer(num_words = max_words+1)# Only the most common 'num_words - 1' words will be kept
tokenizer.fit_on_texts(new_texts) 
data_aux = tokenizer.texts_to_sequences(new_texts)
print(tokenizer.word_index) # Dictionary

data_new = pad_sequences(data_aux, padding="post", maxlen=max_len) # it is necesary because tensor must have the same lenght.
# Texts with lower words than the max number of words in all the texts have to be complete with zeros.
print(data_new)

temp = len(data_new[0])
for i in range(len(data_new)):
  maximo = len(data_new[i])
  if(maximo>temp):
    temp = maximo
maxwords = temp
print("Maximo número de palabras: ", temp)
# Out:
# {'and': 1, 'the': 2, 'to': 3, 'you': 4, 'that': 5, 'it': 6, 'of': 7, 'so': 8, 'like': 9, 'is': 10, 'my': 11, 'in': 12, 'im': 13, 'know': 14, 'this': 15, 'its': 16, 'but': 17, 'just': 18, 'was': 19, 'for': 20, 'on': 21, 'have': 22, 'me': 23, 'be': 24, 'really': 25, 'not': 26, 'dont': 27, 'do': 28, 'all': 29, 'what': 30, 'because': 31, 'one': 32, 'if': 33, 'with': 34, 'about': 35, 'going': 36, 'or': 37, 'we': 38, 'they': 39, 'out': 40, 'are': 41, 'yeah': 42, 'there': 43, 'thats': 44, 'get': 45, 'can': 46, 'people': 47, 'now': 48, 'up': 49, 'at': 50, 'think': 51, 'as': 52, 'go': 53, 'video': 54, 'then': 55, 'see': 56, 'well': 57, 'your': 58, 'when': 59, 'got': 60, 'want': 61, 'them': 62, 'he': 63, 'been': 64, 'right': 65, 'some': 66, 'ive': 67, 'good': 68, 'had': 69, 'from': 70, 'time': 71, 'were': 72, 'gonna': 73, 'would': 74, 'guys': 75, 'will': 76, 'which': 77, 'how': 78, 'oh': 79, 'two': 80, 'lot': 81, 'okay': 82, 'make': 83, 'no': 84, 'here': 85, 'more': 86, 'little': 87, 'youre': 88, 'say': 89, 'something': 90, 'kind': 91, 'who': 92, 'thing': 93, 'an': 94, 'ill': 95, 'very': 96, 'much': 97, 'actually': 98, 'things': 99, 'back': 100, 'other': 101, 'cause': 102, 'am': 103, 'she': 104, 'stuff': 105, 'doing': 106, 'even': 107, 'day': 108, 'videos': 109, 'mean': 110, 'by': 111, 'way': 112, 'love': 113, 'why': 114, 'new': 115, 'theyre': 116, 'theres': 117, 'did': 118, 'has': 119, 'put': 120, 'cant': 121, 'didnt': 122, 'also': 123, 'three': 124, 'first': 125, 'pretty': 126, 'over': 127, 'their': 128, 'too': 129, 'her': 130, 'those': 131, 'these': 132, 'his': 133, 'probably': 134, 'should': 135, 'any': 136, 'into': 137, 'off': 138, 'look': 139, 'went': 140, 'last': 141, 'maybe': 142, 'said': 143, 'come': 144, 'talk': 145, 'youtube': 146, 'today': 147, 'where': 148, 'could': 149, 'still': 150, 'only': 151, 'week': 152, 'need': 153, 'down': 154, 'year': 155, 'anyway': 156, 'tell': 157, 'bit': 158, 'him': 159, 'work': 160, 'again': 161, 'made': 162, 'cool': 163, 'wanted': 164, 'whatever': 165, 'take': 166, 'being': 167, 'before': 168, 'five': 169, 'than': 170, 'great': 171, 'never': 172, 'give': 173, 'thought': 174, 'school': 175, 'around': 176, 'might': 177, 'god': 178, 'awesome': 179, 'anything': 180, 'feel': 181, 'ah': 182, 'hes': 183, 'havent': 184, 'next': 185, 'hey': 186, 'sorry': 187, 'every': 188, 'our': 189, 'long': 190, 'life': 191, 'fun': 192, 'us': 193, 'another': 194, 'hope': 195, 'always': 196, 'doesnt': 197, 'bad': 198, 'sure': 199, 'else': 200, 'big': 201, 'getting': 202, 'lets': 203, 'try': 204, 'whole': 205, 'bye': 206, 'let': 207, 'guess': 208, 'done': 209, 'making': 210, 'most': 211, 'happy': 212, 'friends': 213, 'kinda': 214, 'four': 215, 'after': 216, 'ever': 217, 'many': 218, 'find': 219, 'show': 220, 'basically': 221, 'hair': 222, 'same': 223, 'twenty': 224, 'different': 225, 'everyone': 226, 'better': 227, 'talking': 228, 'hundred': 229, 'use': 230, 'through': 231, 'trying': 232, 'though': 233, 'thank': 234, 'christmas': 235, 'watching': 236, 'check': 237, 'everything': 238, 'keep': 239, 'start': 240, 'yes': 241, 'shes': 242, 'number': 243, 'says': 244, 'music': 245, 'saying': 246, 'days': 247, 'everybody': 248, 'name': 249, 'best': 250, 'watch': 251, 'book': 252, 'person': 253, 'remember': 254, 'since': 255, 'blog': 256, 'whats': 257, 'id': 258, 'does': 259, 'guy': 260, 'night': 261, 'live': 262, 'nice': 263, 'money': 264, 'point': 265, 'years': 266, 'called': 267, 'looking': 268, 'while': 269, 'someone': 270, 'old': 271, 'channel': 272, 'man': 273, 'job': 274, 'amazing': 275, 'few': 276, 'care': 277, 'soon': 278, 'read': 279, 'part': 280, 'weird': 281, 'myself': 282, 'thinking': 283, 'makes': 284, 'came': 285, 'started': 286, 'weeks': 287, 'hi': 288, 'away': 289, 'couple': 290, 'used': 291, 'movie': 292, 'six': 293, 'friend': 294, 'world': 295, 'sort': 296, 'thousand': 297, 'real': 298, 'reason': 299, 'quite': 300, 'already': 301, 'song': 302, 'believe': 303, 'question': 304, 'girl': 305, 'ten': 306, 'end':  ...
# [[  65   59   39 ...    8  237    6]
#  [ 523   12 2183 ...  373   20  236]
#  [ 701  257   49 ...    0    0    0]
#  ...
#  [  72  176  193 ...  381   66  603]
#  [1288  165  537 ...   24  212   35]
#  [  39   72   36 ...  239    4 2344]]
# Maximo número de palabras:  300

# %%
from collections import Counter
vocab = Counter()
for i in range(len(new_texts)):
  vocab.update(new_texts[i])

# %%
word_index = {t[0]: i+1 for i,t in enumerate(vocab.most_common(max_words))}

# %%
emb_dim = 300
embeddings_index = {}
f = open('glove.6B.'+str(emb_dim)+'d.txt')
for line in f:
  values = line.split()
  word = values[0]
  coefs = np.asarray(values[1:], dtype='float32')
  embeddings_index[word] = coefs
f.close()

embedding_matrix = np.zeros((len(word_index), emb_dim))
for word, i in word_index.items():
    if i >= max_words:
      continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
word_index.items()
# Out:
# dict_items([('and', 1), ('to', 2), ('the', 3), ('you', 4), ('that', 5), ('of', 6), ('it', 7), ('like', 8), ('is', 9), ('Im', 10), ('in', 11), ('my', 12), ('know', 13), ('this', 14), ('so', 15), ('was', 16), ('just', 17), ('on', 18), ('for', 19), ('have', 20), ('its', 21), ('but', 22), ('me', 23), ('be', 24), ('really', 25), ('And', 26), ('not', 27), ('dont', 28), ('do', 29), ('So', 30), ('because', 31), ('all', 32), ('with', 33), ('about', 34), ('one', 35), ('what', 36), ('going', 37), ('or', 38), ('out', 39), ('if', 40), ('are', 41), ('get', 42), ('we', 43), ('they', 44), ('can', 45), ('there', 46), ('up', 47), ('people', 48), ('at', 49), ('think', 50), ('video', 51), ('thats', 52), ('as', 53), ('go', 54), ('yeah', 55), ('then', 56), ('now', 57), ('your', 58), ('got', 59), ('want', 60), ('see', 61), ('them', 62), ('when', 63), ('been', 64), ('Ive', 65), ('But', 66), ('Its', 67), ('had', 68), ('right', 69), ('from', 70), ('some', 71), ('good', 72), ('time', 73), ('gonna', 74), ('guys', 75), ('would', 76), ('will', 77), ('lot', 78), ('he', 79), ('were', 80), ('make', 81), ('which', 82), ('more', 83), ('little', 84), ('two', 85), ('here', 86), ('how', 87), ('say', 88), ('well', 89), ('something', 90), ('You', 91), ('thing', 92), ('kind', 93), ('an', 94), ('Ill', 95), ('who', 96), ('much', 97), ('youre', 98), ('very', 99), ('no', 100), ('back', 101), ('things', 102), ('other', 103), ('actually', 104), ('am', 105), ('doing', 106), ('stuff', 107), ('It', 108), ('videos', 109), ('cause', 110), ('mean', 111), ('day', 112), ('The', 113), ('way', 114), ('even', 115), ('love', 116), ('by', 117), ('has', 118), ('cant', 119), ('didnt', 120), ('put', 121), ('did', 122), ('over', 123), ('pretty', 124), ('three', 125), ('why', 126), ('their', 127), ('she', 128), ('too', 129), ('first', 130), ('Okay', 131), ('her', 132), ('Yeah', 133), ('also', 134), ('those', 135), ('oh', 136), ('into', 137), ('off', 138), ('should', 139), ('new', 140), ('any', 141), ('went', 142), ('Oh', 143), ('theyre', 144), ('said', 145), ('theres', 146), ('probably', 147), ('his', 148), ('these', 149), ('talk', 150), ('last', 151), ('could', 152), ('okay', 153), ('week', 154), ('down', 155), ('still', 156), ('YouTube', 157), ('look', 158), ('only', 159), ('need', 160), ('This', 161), ('where', 162), ('come', 163), ('bit', 164), ('him', 165), ('year', 166), ('work', 167), ('made', 168), ('today', 169), ('tell', 170), ('wanted', 171), ('cool', 172), ('again', 173), ('Well', 174), ('maybe', 175), ('being', 176), ('take', 177), ('before', 178), ('than', 179), ('If', 180), ('whatever', 181), ('around', 182), ('thought', 183), ('great', 184), ('give', 185), ('Thats', 186), ('five', 187), ('might', 188), ('school', 189), ('never', 190), ('feel', 191), ('God', 192), ('havent', 193), ('anything', 194), ('Now', 195), ('long', 196), ('fun', 197), ('our', 198), ('next', 199), ('every', 200), ('always', 201), ('life', 202), ('else', 203), ('hope', 204), ('doesnt', 205), ('us', 206), ('sure', 207), ('whole', 208), ('bad', 209), ('getting', 210), ('big', 211), ('try', 212), ('another', 213), ('awesome', 214), ('done', 215), ('Like', 216), ('What', 217), ('making', 218), ('guess', 219), ('friends', 220), ('many', 221), ('kinda', 222), ('ever', 223), ('hair', 224), ('same', 225), ('sorry', 226), ('find', 227), ('different', 228), ('four', 229), ('My', 230), ('talking', 231), ('twenty', 232), ('hundred', 233), ('better', 234), ('after', 235), ('hes', 236), ('through', 237), ('most', 238), ('trying', 239), ('let', 240), ('use', 241), ('though', 242), ('Christmas', 243), ('We', 244), ('show', 245), ('watching', 246), ('everyone', 247), ('happy', 248), ('ah', 249), ('says', 250), ('everything', 251), ('basically', 252), ('keep', 253), ('start', 254), ('anyway', 255), ('saying', 256), ('name', 257), ('They', 258), ('That', 259), ('person', 260), ('days', 261), ('best', 262), ('music', 263), ('lets', 264), ('guy', 265), ('book', 266), ('money', 267), ('watch', 268), ('point', 269), ('called', ...

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.038466  , -0.039792  ,  0.082747  , ..., -0.33427   ,
#          0.011807  ,  0.059703  ],
#        [-0.25756001, -0.057132  , -0.67189997, ..., -0.16043   ,
#          0.046744  , -0.070621  ],
#        ...,
#        [-0.27827001,  0.36035001, -0.37976   , ...,  0.23337001,
#          0.44327   , -0.11329   ],
#        [-0.27961001,  0.13732   ,  0.043514  , ...,  0.39008   ,
#         -0.32460999, -0.01826   ],
#        [ 0.33686   ,  0.23996   , -0.34485   , ..., -0.48993   ,
#         -0.60655999, -0.20739   ]])

# %%
def build_model(reg=.0001,drop=0.4):
  input_text = Input(shape=(max_len,))
  embedding = Embedding(max_words, emb_dim, mask_zero=True, weights=[embedding_matrix], input_length=max_len, trainable=False)(input_text)

  LSTM_1 = Bidirectional(LSTM(512, return_sequences= False,recurrent_dropout=drop, dropout=drop), name="BiLSTM")(embedding)
  output = Dense(1, activation='sigmoid')(LSTM_1)
  model = Model(inputs=[input_text], outputs=output)
  # model.summary()
  model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
  return model

# %% [markdown]
# ### Modify the following variable between the options:
# - Openess to experience: "Open"
# - Conscientiousness: "Cons"
# - Extraversion: "Extr"
# - Agreeableness: "Agr"
# - Emotional stability: "Emot"

# %%
trait = 'Emot'

# %%
#Load labels
import pandas as pd
path_base='LabelsClassification.csv'
labels_data = pd.read_csv(path_base,delimiter=',')
y = list(labels_data[trait])
y = np.asarray(y)
y = y.reshape(-1,1)

# %%
batch_size=32

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=5)
kf.get_n_splits(data_new)
i=0
epochs=20

score_test=[]
pred_test=[]
y_orig=[]

data_new=np.array(data_new)

for train_index, test_index in kf.split(data_new):
  i=i+1
  print("Fold :",i)
  X_train, X_test = data_new[train_index], data_new[test_index]
  y_train, y_test = y[train_index], y[test_index]
  # Adjust to batch size
  X_train, X_test = X_train[:(int(len(X_train)/batch_size))*batch_size], X_test[:int(len(X_test)/batch_size)*batch_size]
  y_train, y_test = y_train[:(int(len(y_train)/batch_size))*batch_size], y_test[:int(len(y_test)/batch_size)*batch_size]

  with tf.Session() as session:
    K.set_session(session)
    session.run(tf.global_variables_initializer()) 
    session.run(tf.tables_initializer())
    #Create model
    GloVe_BiDirectional_model = build_model(reg=.0001,drop=0.5)
    
    checkpoint = ModelCheckpoint("best_model1.hdf5", monitor='val_accuracy', verbose=0,save_best_only=True, mode='auto', period=1)
    model_elmo = GloVe_BiDirectional_model.fit(np.array(X_train), y_train, validation_data=(np.array(X_test), y_test),
                                              epochs=epochs, batch_size=batch_size,verbose=0,callbacks=[checkpoint])

    GloVe_BiDirectional_model.load_weights('best_model1.hdf5')
    test_preds = GloVe_BiDirectional_model.predict(np.array(X_test))
    score_test.append(test_preds)
    pred_test.append(np.round(test_preds))
    y_orig.append(y_test)
# Out:
# Fold : 1
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py:3994: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Fold : 2
# Fold : 3
# Fold : 4
# Fold : 5

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn import metrics

y_total=np.vstack(y_orig)
z_total=np.vstack(pred_test)
y_scores=np.vstack(score_test)

acc=accuracy_score(y_total,z_total)
c_m=confusion_matrix(y_total,z_total)
param=precision_recall_fscore_support(y_total, z_total, pos_label=1, average='weighted')
sensi=(c_m[1][1])/(c_m[1][1]+c_m[1][0])
speci=(c_m[0][0])/(c_m[0][0]+c_m[0][1])
f1=param[2]
fpr, tpr, thresholds = metrics.roc_curve(y_total, y_scores)
auc=metrics.auc(fpr, tpr)

print("Accuracy=",acc*100)
print("Sensivity = ", sensi)
print("Specificity = ", speci)
print("F1score = ", f1)
print("AUC= ", auc)
# Out:
# Accuracy= 59.375
# Sensivity =  0.610062893081761
# Specificity =  0.577639751552795
# F1score =  0.5936547702766056
# AUC=  0.5870932458299153

# %%
plt.figure(figsize=(8,8))
plt.plot(fpr,tpr,label="Emototional stability (AUC ="+str(np.round(auc,2))+")",color='blue',linewidth=3)
plt.xlabel('False positive rate',fontsize=20)
plt.ylabel('True positive rate',fontsize=20)
plt.title('ROC curve Emototional stability',fontsize=24)
plt.legend(loc="best",fontsize=18)
plt.tick_params(labelsize=18)
plt.grid()
plt.savefig('curva_ROC_Emototional.png')
plt.show()

# %%
np.savetxt("y_labels_Emot.txt",y_total) 
np.savetxt("z_total_Emot.txt",z_total) 
np.savetxt("y_scores_Emot.txt",y_scores)
